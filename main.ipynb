# %%
#imports
import pandas
import requests
from dotenv import load_dotenv
import os

load_dotenv()  # Loads .env variables
# Out:
# True

# %%
#functions
def get_steam_app_list():
    url = "https://api.steampowered.com/IStoreService/GetAppList/v1/"
    params = {
        "key": os.getenv("STEAM_WEB_API_KEY"),
        "include_games": True,
        "include_dlc": False,
        "include_software": False,
        "include_videos": False,
        "include_hardware": False,
        "max_results": 20
    }

    response = requests.get(url, params=params)
    response.raise_for_status()  # Raise error if something goes wrong

    data = response.json()

    apps = data.get("response", {}).get("apps", [])
    return apps

# %%
apps = get_steam_app_list()
print(f"Total apps: {len(apps)}")

# Print the first 10 entries as an example
for app in apps[:10]:
    print(app)
# Out:
# Total apps: 20
# {'appid': 10, 'name': 'Counter-Strike', 'last_modified': 1745368572, 'price_change_number': 31509480}
# {'appid': 20, 'name': 'Team Fortress Classic', 'last_modified': 1745368565, 'price_change_number': 31509480}
# {'appid': 30, 'name': 'Day of Defeat', 'last_modified': 1745368580, 'price_change_number': 31509480}
# {'appid': 40, 'name': 'Deathmatch Classic', 'last_modified': 1745368570, 'price_change_number': 31509480}
# {'appid': 50, 'name': 'Half-Life: Opposing Force', 'last_modified': 1745368539, 'price_change_number': 31509480}
# {'appid': 60, 'name': 'Ricochet', 'last_modified': 1745368568, 'price_change_number': 31509480}
# {'appid': 70, 'name': 'Half-Life', 'last_modified': 1745368462, 'price_change_number': 32053974}
# {'appid': 80, 'name': 'Counter-Strike: Condition Zero', 'last_modified': 1745368574, 'price_change_number': 31509480}
# {'appid': 130, 'name': 'Half-Life: Blue Shift', 'last_modified': 1745368541, 'price_change_number': 31509480}
# {'appid': 220, 'name': 'Half-Life 2', 'last_modified': 1745368545, 'price_change_number': 32053974}
